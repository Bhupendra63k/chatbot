# %%
import tkinter as tk
from tkinter import scrolledtext
import nltk
from nltk.chat.util import Chat, reflections

# Download required NLTK data
nltk.download('punkt')

# Define chatbot patterns and responses
patterns = [
    (r'hi|hello|hey', ['Hello, how can I help you today?', 'Hi there! How can I assist you?']),
    (r'how are you?', ['I am doing great, thank you!', 'I am good, how about you?']),
    (r'what is your name?', ['I am a chatbot created by you!', 'You can call me Chatbot.']),
    (r'bye|goodbye', ['Goodbye! Have a great day!', 'Bye! Take care!']),
    (r'what can you do?', ['I can chat with you and answer simple questions.', 'I can help you with information or just chat with you!']),
    (r'(.*) (your|my) (.*)', ['Sorry, I am not sure about that.', 'Can you clarify your question?']),
    (r'(.*) help (.*)', ['Sure, I am here to help you. What do you need help with?']),
    (r'(.*)', ['Sorry, I didn’t understand that. Can you rephrase?', 'I’m not sure what you mean. Please try again.'])
]

# Create a chatbot with the defined patterns
chatbot = Chat(patterns, reflections)

# Function to get chatbot response
def get_response():
    user_input = user_input_box.get()
    if user_input.strip() != "":  # Ensure there's text entered
        chat_display.insert(tk.END, "You: " + user_input + "\n")
        user_input_box.delete(0, tk.END)  # Clear input box
        
        if user_input.lower() in ['bye', 'goodbye']:
            chat_display.insert(tk.END, "Chatbot: Goodbye! Have a great day!\n")
            window.quit()  # Close the chat window
        else:
            response = chatbot.respond(user_input)
            # If the chatbot doesn't have a response, repeat the user's message
            if response is None:
                response = f"You said: {user_input}"
            chat_display.insert(tk.END, "Chatbot: " + response + "\n")
        chat_display.yview(tk.END)  # Auto-scroll to the latest message

# Set up the main Tkinter window
window = tk.Tk()
window.title("Chatbot")

# Set the size of the window (bigger size)
window.geometry("600x700")  # Increase window size

# Get the screen width and height to center the window
screen_width = window.winfo_screenwidth()
screen_height = window.winfo_screenheight()

# Calculate the position to center the window on the screen
position_top = int(screen_height / 2 - 350)  # 350 is half the height of the window
position_right = int(screen_width / 2 - 300)  # 300 is half the width of the window

# Position the window in the center
window.geometry(f'600x700+{position_right}+{position_top}')

# Create a scrollable text area to display chat history
chat_display = scrolledtext.ScrolledText(window, wrap=tk.WORD, width=70, height=25)
chat_display.place(x=20, y=20)
chat_display.insert(tk.END, "Chatbot: Hello, I am your chatbot. Type 'bye' to end the conversation.\n")
chat_display.config(state=tk.DISABLED)  # Make the text box read-only initially

# Create a user input box
user_input_box = tk.Entry(window, width=60)
user_input_box.place(x=20, y=630)

# Create a send button
send_button = tk.Button(window, text="Send", width=10, command=get_response)
send_button.place(x=500, y=625)

# Run the Tkinter main loop
window.mainloop()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\naray\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import tkinter as tk
from tkinter import scrolledtext
import nltk
from nltk.chat.util import Chat, reflections

# Download required NLTK data
nltk.download('punkt')

# Define chatbot patterns and responses
patterns = [
    (r'hi|hello|hey', ['Hello, how can I help you today?', 'Hi there! How can I assist you?']),
    (r'how are you?', ['I am doing great, thank you!', 'I am good, how about you?']),
    (r'what is your name?', ['I am a chatbot created by you!', 'You can call me Chatbot.']),
    (r'bye|goodbye', ['Goodbye! Have a great day!', 'Bye! Take care!']),
    (r'what can you do?', ['I can chat with you and answer simple questions.', 'I can help you with information or just chat with you!']),
    (r'(.*) (your|my) (.*)', ['Sorry, I am not sure about that.', 'Can you clarify your question?']),
    (r'(.*) help (.*)', ['Sure, I am here to help you. What do you need help with?']),
    (r'(.*)', ['Sorry, I didn’t understand that. Can you rephrase?', 'I’m not sure what you mean. Please try again.'])
]

# Create a chatbot with the defined patterns
chatbot = Chat(patterns, reflections)

# Function to get chatbot response
def get_response():
    user_input = user_input_box.get()
    if user_input.strip() != "":  # Ensure there's text entered
        chat_display.config(state=tk.NORMAL)  # Enable text box to insert text
        chat_display.insert(tk.END, "You: " + user_input + "\n")
        user_input_box.delete(0, tk.END)  # Clear input box
        
        if user_input.lower() in ['bye', 'goodbye']:
            chat_display.insert(tk.END, "Chatbot: Goodbye! Have a great day!\n")
            window.quit()  # Close the chat window
        else:
            response = chatbot.respond(user_input)
            # If the chatbot doesn't have a response, repeat the user's message
            if response is None:
                response = f"You said: {user_input}"
            chat_display.insert(tk.END, "Chatbot: " + response + "\n")
        chat_display.config(state=tk.DISABLED)  # Disable text box to prevent manual editing
        chat_display.yview(tk.END)  # Auto-scroll to the latest message

# Set up the main Tkinter window
window = tk.Tk()
window.title("Chatbot")

# Set the size of the window (bigger size)
window.geometry("600x700")  # Increase window size

# Get the screen width and height to center the window
screen_width = window.winfo_screenwidth()
screen_height = window.winfo_screenheight()

# Calculate the position to center the window on the screen
position_top = int(screen_height / 2 - 350)  # 350 is half the height of the window
position_right = int(screen_width / 2 - 300)  # 300 is half the width of the window

# Position the window in the center
window.geometry(f'600x700+{position_right}+{position_top}')

# Create a scrollable text area to display chat history
chat_display = scrolledtext.ScrolledText(window, wrap=tk.WORD, width=70, height=25)
chat_display.place(x=20, y=20)
chat_display.insert(tk.END, "Chatbot: Hello, I am your chatbot. Type 'bye' to end the conversation.\n")
chat_display.config(state=tk.DISABLED)  # Make the text box read-only initially

# Create a user input box
user_input_box = tk.Entry(window, width=60)
user_input_box.place(x=20, y=630)

# Create a send button
send_button = tk.Button(window, text="Send", width=10, command=get_response)
send_button.place(x=500, y=625)

# Run the Tkinter main loop
window.mainloop()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\naray\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import tkinter as tk
from tkinter import scrolledtext
import nltk
from nltk.chat.util import Chat, reflections

# Download required NLTK data
nltk.download('punkt')

# Define chatbot patterns and responses
patterns = [
    (r'hi|hello|hey', ['Hello, how can I help you today?', 'Hi there! How can I assist you?']),
    (r'how are you?', ['I am doing great, thank you!', 'I am good, how about you?']),
    (r'what is your name?', ['I am a chatbot created by you!', 'You can call me Chatbot.']),
    (r'bye|goodbye', ['Goodbye! Have a great day!', 'Bye! Take care!']),
    (r'what can you do?', ['I can chat with you and answer simple questions.', 'I can help you with information or just chat with you!']),
    (r'(.*) (your|my) (.*)', ['Sorry, I am not sure about that.', 'Can you clarify your question?']),
    (r'(.*) help (.*)', ['Sure, I am here to help you. What do you need help with?']),
    (r'(.*)', ['Sorry, I didn’t understand that. Can you rephrase?', 'I’m not sure what you mean. Please try again.'])
]

# Create a chatbot with the defined patterns
chatbot = Chat(patterns, reflections)

# Function to get chatbot response
def get_response():
    user_input = user_input_box.get()
    if user_input.strip() != "":  # Ensure there's text entered
        chat_display.config(state=tk.NORMAL)  # Enable text box to insert text
        chat_display.insert(tk.END, "You: " + user_input + "\n")
        user_input_box.delete(0, tk.END)  # Clear input box
        
        if user_input.lower() in ['bye', 'goodbye']:
            chat_display.insert(tk.END, "Chatbot: Goodbye! Have a great day!\n")
            window.quit()  # Close the chat window
        else:
            response = chatbot.respond(user_input)
            # If the chatbot doesn't have a response, repeat the user's message
            if response is None:
                response = f"You said: {user_input}"
            chat_display.insert(tk.END, "Chatbot: " + response + "\n")
        chat_display.config(state=tk.DISABLED)  # Disable text box to prevent manual editing
        chat_display.yview(tk.END)  # Auto-scroll to the latest message

# Set up the main Tkinter window
window = tk.Tk()
window.title("Chatbot")

# Set the size of the window (bigger size)
window.geometry("600x700")  # Increase window size

# Get the screen width and height to center the window
screen_width = window.winfo_screenwidth()
screen_height = window.winfo_screenheight()

# Calculate the position to center the window on the screen
position_top = int(screen_height / 2 - 350)  # 350 is half the height of the window
position_right = int(screen_width / 2 - 300)  # 300 is half the width of the window

# Position the window in the center
window.geometry(f'600x700+{position_right}+{position_top}')

# Create a scrollable text area to display chat history with increased size
chat_display = scrolledtext.ScrolledText(window, wrap=tk.WORD, width=80, height=30)  # Increased width and height
chat_display.place(x=20, y=20)
chat_display.insert(tk.END, "Chatbot: Hello, I am your chatbot. Type 'bye' to end the conversation.\n")
chat_display.config(state=tk.DISABLED)  # Make the text box read-only initially

# Create a user input box
user_input_box = tk.Entry(window, width=60)
user_input_box.place(x=20, y=630)

# Create a send button
send_button = tk.Button(window, text="Send", width=10, command=get_response)
send_button.place(x=500, y=625)

# Run the Tkinter main loop
window.mainloop()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\naray\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import tkinter as tk
from tkinter import scrolledtext
import nltk
from nltk.chat.util import Chat, reflections

# Download required NLTK data
nltk.download('punkt')

# Define chatbot patterns and responses
patterns = [
    (r'hi|hello|hey', ['Hello, how can I help you today?', 'Hi there! How can I assist you?']),
    (r'how are you?', ['I am doing great, thank you!', 'I am good, how about you?']),
    (r'what is your name?', ['I am a chatbot created by you!', 'You can call me Chatbot.']),
    (r'bye|goodbye', ['Goodbye! Have a great day!', 'Bye! Take care!']),
    (r'what can you do?', ['I can chat with you and answer simple questions.', 'I can help you with information or just chat with you!']),
    (r'(.*) (your|my) (.*)', ['Sorry, I am not sure about that.', 'Can you clarify your question?']),
    (r'(.*) help (.*)', ['Sure, I am here to help you. What do you need help with?']),
    (r'(.*)', ['Sorry, I didn’t understand that. Can you rephrase?', 'I’m not sure what you mean. Please try again.'])
]

# Create a chatbot with the defined patterns
chatbot = Chat(patterns, reflections)

# Function to get chatbot response
def get_response():
    user_input = user_input_box.get()
    if user_input.strip() != "":  # Ensure there's text entered
        chat_display.config(state=tk.NORMAL)  # Enable text box to insert text
        chat_display.insert(tk.END, "You: " + user_input + "\n")
        user_input_box.delete(0, tk.END)  # Clear input box
        
        if user_input.lower() in ['bye', 'goodbye']:
            chat_display.insert(tk.END, "Chatbot: Goodbye! Have a great day!\n")
            window.quit()  # Close the chat window
        else:
            response = chatbot.respond(user_input)
            # If the chatbot doesn't have a response, repeat the user's message
            if response is None:
                response = f"You said: {user_input}"
            chat_display.insert(tk.END, "Chatbot: " + response + "\n")
        chat_display.config(state=tk.DISABLED)  # Disable text box to prevent manual editing
        chat_display.yview(tk.END)  # Auto-scroll to the latest message

# Set up the main Tkinter window
window = tk.Tk()
window.title("Chatbot")
window.geometry("600x700")

# Get the screen width and height to center the window
screen_width = window.winfo_screenwidth()
screen_height = window.winfo_screenheight()

# Calculate the position to center the window on the screen
position_top = int(screen_height / 2 - 350)  # 350 is half the height of the window
position_right = int(screen_width / 2 - 300)  # 300 is half the width of the window

# Position the window in the center
window.geometry(f'600x700+{position_right}+{position_top}')

# Set a background color and font for the window
window.config(bg='#f5f5f5')  # Light grey background

# Create a label for the title
title_label = tk.Label(window, text="Chatbot", font=("Arial", 24, "bold"), bg='#f5f5f5', fg="#2a2a2a")
title_label.place(x=250, y=10)

# Create a scrollable text area to display chat history with increased size and decoration
chat_display = scrolledtext.ScrolledText(window, wrap=tk.WORD, width=80, height=30, font=("Arial", 12), bg="#e8e8e8", fg="#2a2a2a", bd=2, relief="solid")
chat_display.place(x=20, y=60)
chat_display.insert(tk.END, "Chatbot: Hello, I am your chatbot. Type 'bye' to end the conversation.\n")
chat_display.config(state=tk.DISABLED)  # Make the text box read-only initially

# Create a user input box with custom style
user_input_box = tk.Entry(window, width=50, font=("Arial", 14), bd=2, relief="solid", fg="#2a2a2a")
user_input_box.place(x=20, y=620)

# Create a send button with customized style
send_button = tk.Button(window, text="Send", width=10, font=("Arial", 14), bg="#4CAF50", fg="white", relief="raised", command=get_response)
send_button.place(x=500, y=615)

# Add some padding to the window
window.config(padx=20, pady=20)

# Run the Tkinter main loop
window.mainloop()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\naray\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import tkinter as tk
from tkinter import scrolledtext
import nltk
from nltk.chat.util import Chat, reflections

# Download required NLTK data
nltk.download('punkt')

# Define chatbot patterns and responses
patterns = [
    (r'hi|hello|hey', ['Hello, how can I help you today?', 'Hi there! How can I assist you?']),
    (r'how are you?', ['I am doing great, thank you!', 'I am good, how about you?']),
    (r'what is your name?', ['I am a chatbot created by you!', 'You can call me Chatbot.']),
    (r'bye|goodbye', ['Goodbye! Have a great day!', 'Bye! Take care!']),
    (r'what can you do?', ['I can chat with you and answer simple questions.', 'I can help you with information or just chat with you!']),
    (r'(.*) (your|my) (.*)', ['Sorry, I am not sure about that.', 'Can you clarify your question?']),
    (r'(.*) help (.*)', ['Sure, I am here to help you. What do you need help with?']),
    (r'(.*)', ['Sorry, I didn’t understand that. Can you rephrase?', 'I’m not sure what you mean. Please try again.'])
]

# Create a chatbot with the defined patterns
chatbot = Chat(patterns, reflections)

# Function to get chatbot response
def get_response():
    user_input = user_input_box.get()
    if user_input.strip() != "":  # Ensure there's text entered
        chat_display.config(state=tk.NORMAL)  # Enable text box to insert text
        chat_display.insert(tk.END, "You: " + user_input + "\n")
        user_input_box.delete(0, tk.END)  # Clear input box
        
        if user_input.lower() in ['bye', 'goodbye']:
            chat_display.insert(tk.END, "Chatbot: Goodbye! Have a great day!\n")
            window.quit()  # Close the chat window
        else:
            response = chatbot.respond(user_input)
            # If the chatbot doesn't have a response, repeat the user's message
            if response is None:
                response = f"You said: {user_input}"
            chat_display.insert(tk.END, "Chatbot: " + response + "\n")
        chat_display.config(state=tk.DISABLED)  # Disable text box to prevent manual editing
        chat_display.yview(tk.END)  # Auto-scroll to the latest message

# Set up the main Tkinter window
window = tk.Tk()
window.title("Chatbot")
window.geometry("600x700")

# Get the screen width and height to center the window
screen_width = window.winfo_screenwidth()
screen_height = window.winfo_screenheight()

# Calculate the position to center the window on the screen
position_top = int(screen_height / 2 - 350)  # 350 is half the height of the window
position_right = int(screen_width / 2 - 300)  # 300 is half the width of the window

# Position the window in the center
window.geometry(f'600x700+{position_right}+{position_top}')

# Set a background color and font for the window
window.config(bg='#f5f5f5')  # Light grey background

# Create a label for the title
title_label = tk.Label(window, text="Chatbot", font=("Arial", 24, "bold"), bg='#f5f5f5', fg="#2a2a2a")
title_label.place(x=250, y=10)

# Create a scrollable text area to display chat history with increased size and decoration
chat_display = scrolledtext.ScrolledText(window, wrap=tk.WORD, width=80, height=30, font=("Arial", 12), bg="#e8e8e8", fg="#2a2a2a", bd=2, relief="solid")
chat_display.place(x=20, y=60)
chat_display.insert(tk.END, "Chatbot: Hello, I am your chatbot. Type 'bye' to end the conversation.\n")
chat_display.config(state=tk.DISABLED)  # Make the text box read-only initially

# Create a user input box with custom style
user_input_box = tk.Entry(window, width=50, font=("Arial", 14), bd=2, relief="solid", fg="#2a2a2a")
user_input_box.place(x=20, y=620)

# Create a send button with customized style
send_button = tk.Button(window, text="Send", width=10, font=("Arial", 14), bg="#4CAF50", fg="white", relief="raised", command=get_response)
send_button.place(x=500, y=650)  # Increased y-coordinate for more distance between button and input box

# Add some padding to the window
window.config(padx=20, pady=20)

# Run the Tkinter main loop
window.mainloop()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\naray\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import tkinter as tk
from tkinter import scrolledtext
import nltk
from nltk.chat.util import Chat, reflections
from PIL import Image, ImageTk  # Import the Image module from Pillow

# Download required NLTK data
nltk.download('punkt')

# Define chatbot patterns and responses
patterns = [
    (r'hi|hello|hey', ['Hello, how can I help you today?', 'Hi there! How can I assist you?']),
    (r'how are you?', ['I am doing great, thank you!', 'I am good, how about you?']),
    (r'what is your name?', ['I am a chatbot created by you!', 'You can call me Chatbot.']),
    (r'bye|goodbye', ['Goodbye! Have a great day!', 'Bye! Take care!']),
    (r'what can you do?', ['I can chat with you and answer simple questions.', 'I can help you with information or just chat with you!']),
    (r'(.*) (your|my) (.*)', ['Sorry, I am not sure about that.', 'Can you clarify your question?']),
    (r'(.*) help (.*)', ['Sure, I am here to help you. What do you need help with?']),
    (r'(.*)', ['Sorry, I didn’t understand that. Can you rephrase?', 'I’m not sure what you mean. Please try again.'])
]

# Create a chatbot with the defined patterns
chatbot = Chat(patterns, reflections)

# Function to get chatbot response
def get_response():
    user_input = user_input_box.get()
    if user_input.strip() != "":  # Ensure there's text entered
        chat_display.config(state=tk.NORMAL)  # Enable text box to insert text
        chat_display.insert(tk.END, "You: " + user_input + "\n")
        user_input_box.delete(0, tk.END)  # Clear input box
        
        if user_input.lower() in ['bye', 'goodbye']:
            chat_display.insert(tk.END, "Chatbot: Goodbye! Have a great day!\n")
            window.quit()  # Close the chat window
        else:
            response = chatbot.respond(user_input)
            # If the chatbot doesn't have a response, repeat the user's message
            if response is None:
                response = f"You said: {user_input}"
            chat_display.insert(tk.END, "Chatbot: " + response + "\n")
        chat_display.config(state=tk.DISABLED)  # Disable text box to prevent manual editing
        chat_display.yview(tk.END)  # Auto-scroll to the latest message

# Set up the main Tkinter window
window = tk.Tk()
window.title("Chatbot")
window.geometry("600x700")

# Set the icon for the window
window.iconbitmap(r"C:\Users\naray\Downloads\chatboticon.ico")  # Set window icon

# Get the screen width and height to center the window
screen_width = window.winfo_screenwidth()
screen_height = window.winfo_screenheight()

# Calculate the position to center the window on the screen
position_top = int(screen_height / 2 - 350)  # 350 is half the height of the window
position_right = int(screen_width / 2 - 300)  # 300 is half the width of the window

# Position the window in the center
window.geometry(f'600x700+{position_right}+{position_top}')

# Set a background color and font for the window
window.config(bg='#f5f5f5')  # Light grey background

# Load and display the chatbot image
chatbot_image_path = r"C:\Users\naray\Downloads\chatbotai.jpg"  # Image file path
chatbot_image = Image.open(chatbot_image_path)
chatbot_image = chatbot_image.resize((100, 100))  # Resize image to fit the window if needed
chatbot_image_tk = ImageTk.PhotoImage(chatbot_image)

# Display the image on the window
image_label = tk.Label(window, image=chatbot_image_tk, bg='#f5f5f5')
image_label.place(x=250, y=50)  # Adjust position if necessary

# Create a label for the title
title_label = tk.Label(window, text="Chatbot", font=("Arial", 24, "bold"), bg='#f5f5f5', fg="#2a2a2a")
title_label.place(x=250, y=10)

# Create a scrollable text area to display chat history with increased size and decoration
chat_display = scrolledtext.ScrolledText(window, wrap=tk.WORD, width=80, height=30, font=("Arial", 12), bg="#e8e8e8", fg="#2a2a2a", bd=2, relief="solid")
chat_display.place(x=20, y=200)
chat_display.insert(tk.END, "Chatbot: Hello, I am your chatbot. Type 'bye' to end the conversation.\n")
chat_display.config(state=tk.DISABLED)  # Make the text box read-only initially

# Create a user input box with custom style
user_input_box = tk.Entry(window, width=50, font=("Arial", 14), bd=2, relief="solid", fg="#2a2a2a")
user_input_box.place(x=20, y=620)

# Create a send button with customized style
send_button = tk.Button(window, text="Send", width=10, font=("Arial", 14), bg="#4CAF50", fg="white", relief="raised", command=get_response)
send_button.place(x=500, y=650)  # Increased y-coordinate for more distance between button and input box

# Add some padding to the window
window.config(padx=20, pady=20)

# Run the Tkinter main loop
window.mainloop()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\naray\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import tkinter as tk
from tkinter import scrolledtext
import nltk
from nltk.chat.util import Chat, reflections
from PIL import Image, ImageTk  # Import the Image module from Pillow

# Download required NLTK data
nltk.download('punkt')

# Define chatbot patterns and responses
patterns = [
    (r'hi|hello|hey', ['Hello, how can I help you today?', 'Hi there! How can I assist you?']),
    (r'how are you?', ['I am doing great, thank you!', 'I am good, how about you?']),
    (r'what is your name?', ['I am a chatbot created by you!', 'You can call me Chatbot.']),
    (r'bye|goodbye', ['Goodbye! Have a great day!', 'Bye! Take care!']),
    (r'what can you do?', ['I can chat with you and answer simple questions.', 'I can help you with information or just chat with you!']),
    (r'(.*) (your|my) (.*)', ['Sorry, I am not sure about that.', 'Can you clarify your question?']),
    (r'(.*) help (.*)', ['Sure, I am here to help you. What do you need help with?']),
    (r'(.*)', ['Sorry, I didn’t understand that. Can you rephrase?', 'I’m not sure what you mean. Please try again.'])
]

# Create a chatbot with the defined patterns
chatbot = Chat(patterns, reflections)

# Function to get chatbot response
def get_response():
    user_input = user_input_box.get()
    if user_input.strip() != "":  # Ensure there's text entered
        chat_display.config(state=tk.NORMAL)  # Enable text box to insert text
        chat_display.insert(tk.END, "You: " + user_input + "\n")
        user_input_box.delete(0, tk.END)  # Clear input box
        
        if user_input.lower() in ['bye', 'goodbye']:
            chat_display.insert(tk.END, "Chatbot: Goodbye! Have a great day!\n")
            window.quit()  # Close the chat window
        else:
            response = chatbot.respond(user_input)
            # If the chatbot doesn't have a response, repeat the user's message
            if response is None:
                response = f"You said: {user_input}"
            chat_display.insert(tk.END, "Chatbot: " + response + "\n")
        chat_display.config(state=tk.DISABLED)  # Disable text box to prevent manual editing
        chat_display.yview(tk.END)  # Auto-scroll to the latest message

# Set up the main Tkinter window
window = tk.Tk()
window.title("Chatbot")
window.geometry("600x700")

# Set the icon for the window
window.iconbitmap(r"C:\Users\naray\Downloads\chatboticon.ico")  # Set window icon

# Get the screen width and height to center the window
screen_width = window.winfo_screenwidth()
screen_height = window.winfo_screenheight()

# Calculate the position to center the window on the screen
position_top = int(screen_height / 2 - 350)  # 350 is half the height of the window
position_right = int(screen_width / 2 - 300)  # 300 is half the width of the window

# Position the window in the center
window.geometry(f'600x700+{position_right}+{position_top}')

# Set a background color and font for the window
window.config(bg='#f5f5f5')  # Light grey background

# Load and display the chatbot image
chatbot_image_path = r"C:\Users\naray\Downloads\chatbotai.jpg"  # Image file path
chatbot_image = Image.open(chatbot_image_path)
chatbot_image = chatbot_image.resize((100, 100))  # Resize image to fit the window if needed
chatbot_image_tk = ImageTk.PhotoImage(chatbot_image)

# Display the image on the window
image_label = tk.Label(window, image=chatbot_image_tk, bg='#f5f5f5')
image_label.place(relx=0.5, rely=0.2, anchor='center')  # Center image using relative positioning

# Create a label for the title
title_label = tk.Label(window, text="Chatbot", font=("Arial", 24, "bold"), bg='#f5f5f5', fg="#2a2a2a")
title_label.place(relx=0.5, rely=0.3, anchor='center')  # Center title label using relative positioning

# Create a scrollable text area to display chat history with increased size and decoration
chat_display = scrolledtext.ScrolledText(window, wrap=tk.WORD, width=80, height=20, font=("Arial", 12), bg="#e8e8e8", fg="#2a2a2a", bd=2, relief="solid")
chat_display.place(relx=0.5, rely=0.5, anchor='center')  # Center chat display using relative positioning
chat_display.insert(tk.END, "Chatbot: Hello, I am your chatbot. Type 'bye' to end the conversation.\n")
chat_display.config(state=tk.DISABLED)  # Make the text box read-only initially

# Create a user input box with custom style
user_input_box = tk.Entry(window, width=50, font=("Arial", 14), bd=2, relief="solid", fg="#2a2a2a")
user_input_box.place(relx=0.5, rely=0.8, anchor='center')  # Center user input box

# Create a send button with customized style
send_button = tk.Button(window, text="Send", width=10, font=("Arial", 14), bg="#4CAF50", fg="white", relief="raised", command=get_response)
send_button.place(relx=0.5, rely=0.9, anchor='center')  # Center send button

# Add some padding to the window
window.config(padx=20, pady=20)

# Run the Tkinter main loop
window.mainloop()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\naray\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import tkinter as tk
from tkinter import scrolledtext
import nltk
from nltk.chat.util import Chat, reflections
from PIL import Image, ImageTk  # Import the Image module from Pillow

# Download required NLTK data
nltk.download('punkt')

# Define chatbot patterns and responses
patterns = [
    (r'hi|hello|hey', ['Hello, how can I help you today?', 'Hi there! How can I assist you?']),
    (r'how are you?', ['I am doing great, thank you!', 'I am good, how about you?']),
    (r'what is your name?', ['I am a chatbot created by you!', 'You can call me Chatbot.']),
    (r'bye|goodbye', ['Goodbye! Have a great day!', 'Bye! Take care!']),
    (r'what can you do?', ['I can chat with you and answer simple questions.', 'I can help you with information or just chat with you!']),
    (r'(.*) (your|my) (.*)', ['Sorry, I am not sure about that.', 'Can you clarify your question?']),
    (r'(.*) help (.*)', ['Sure, I am here to help you. What do you need help with?']),
    (r'(.*)', ['Sorry, I didn’t understand that. Can you rephrase?', 'I’m not sure what you mean. Please try again.'])
]

# Create a chatbot with the defined patterns
chatbot = Chat(patterns, reflections)

# Function to get chatbot response
def get_response():
    user_input = user_input_box.get()
    if user_input.strip() != "":  # Ensure there's text entered
        chat_display.config(state=tk.NORMAL)  # Enable text box to insert text
        chat_display.insert(tk.END, "You: " + user_input + "\n")
        user_input_box.delete(0, tk.END)  # Clear input box
        
        if user_input.lower() in ['bye', 'goodbye']:
            chat_display.insert(tk.END, "Chatbot: Goodbye! Have a great day!\n")
            window.quit()  # Close the chat window
        else:
            response = chatbot.respond(user_input)
            # If the chatbot doesn't have a response, repeat the user's message
            if response is None:
                response = f"You said: {user_input}"
            chat_display.insert(tk.END, "Chatbot: " + response + "\n")
        chat_display.config(state=tk.DISABLED)  # Make the text box read-only initially
        chat_display.yview(tk.END)  # Auto-scroll to the latest message

# Set up the main Tkinter window
window = tk.Tk()
window.title("Chatbot")
window.geometry("600x700")

# Set the icon for the window
window.iconbitmap(r"C:\Users\naray\Downloads\chatboticon.ico")  # Set window icon

# Get the screen width and height to center the window
screen_width = window.winfo_screenwidth()
screen_height = window.winfo_screenheight()

# Calculate the position to center the window on the screen
position_top = int(screen_height / 2 - 350)  # 350 is half the height of the window
position_right = int(screen_width / 2 - 300)  # 300 is half the width of the window

# Position the window in the center
window.geometry(f'600x700+{position_right}+{position_top}')

# Set a background color and font for the window
window.config(bg='#d3f4f9')  # Light blue background

# Load and display the chatbot image
chatbot_image_path = r"C:\Users\naray\Downloads\chatbotai.jpg"  # Image file path
chatbot_image = Image.open(chatbot_image_path)
chatbot_image = chatbot_image.resize((100, 100))  # Resize image to fit the window if needed
chatbot_image_tk = ImageTk.PhotoImage(chatbot_image)

# Display the image on the window with some distance up the screen
image_label = tk.Label(window, image=chatbot_image_tk, bg='#d3f4f9')
image_label.place(relx=0.5, rely=0.1, anchor='center')  # Moved the image higher by changing rely value

# Create a label for the title
title_label = tk.Label(window, text="Chatbot", font=("Arial", 24, "bold"), bg='#d3f4f9', fg="#2a2a2a")
title_label.place(relx=0.5, rely=0.2, anchor='center')  # Center title label below the image

# Create a scrollable text area to display chat history with increased size and decoration
chat_display = scrolledtext.ScrolledText(window, wrap=tk.WORD, width=80, height=20, font=("Arial", 12), bg="#e8e8e8", fg="#2a2a2a", bd=2, relief="solid")
chat_display.place(relx=0.5, rely=0.5, anchor='center')  # Center chat display using relative positioning
chat_display.insert(tk.END, "Chatbot: Hello, I am your chatbot. Type 'bye' to end the conversation.\n")
chat_display.config(state=tk.DISABLED)  # Make the text box read-only initially

# Create a user input box with custom style
user_input_box = tk.Entry(window, width=50, font=("Arial", 14), bd=2, relief="solid", fg="#2a2a2a")
user_input_box.place(relx=0.5, rely=0.8, anchor='center')  # Center user input box

# Create a send button with customized style
send_button = tk.Button(window, text="Send", width=10, font=("Arial", 14), bg="#4CAF50", fg="white", relief="raised", command=get_response)
send_button.place(relx=0.5, rely=0.9, anchor='center')  # Center send button

# Add some padding to the window
window.config(padx=20, pady=20)

# Run the Tkinter main loop
window.mainloop()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\naray\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import tkinter as tk
from tkinter import scrolledtext
import nltk
from nltk.chat.util import Chat, reflections
from PIL import Image, ImageTk
import datetime  # Import datetime for dynamic time and date

# Download required NLTK data
nltk.download('punkt')

# Define chatbot patterns and responses
patterns = [
    (r'hi|hello|hey', ['Hello, how can I help you today?', 'Hi there! How can I assist you?']),
    (r'how are you?', ['I am doing great, thank you!', 'I am good, how about you?']),
    (r'what is your name?', ['I am a chatbot created by you!', 'You can call me Chatbot.']),
    (r'bye|goodbye', ['Goodbye! Have a great day!', 'Bye! Take care!']),
    (r'what can you do?', ['I can chat with you and answer simple questions.', 'I can help you with information or just chat with you!']),
    (r'(.*) your (.*)', ['Sorry, I am not sure about that.', 'Can you clarify your question?']),
    (r'(.*) help (.*)', ['Sure, I am here to help you. What do you need help with?']),
    
    # Dynamic time and date responses
    (r'what is the time?', [f"The current time is: {datetime.datetime.now().strftime('%H:%M:%S')}"]),
    (r'what is today\'s date?', [f"Today's date is: {datetime.datetime.now().strftime('%Y-%m-%d')}"]),
    
    # Fun responses
    (r'(.*) (joke|funny)', ['Why don’t skeletons fight each other? They don’t have the guts!', 'Why did the chicken join a band? Because it had the drumsticks!']),
    (r'(.*) (movie|film) (.*)', ['I love movies! What genre are you interested in?', 'I’m always up for a good movie. What do you want to know about?']),
    
    # Compliments and Friendly Responses
    (r'(.*) (beautiful|good|great)', ['Thank you! You are amazing too!', 'You are kind!']),
    (r'(.*) (sad|unhappy)', ['I’m sorry to hear that. I’m here if you need someone to talk to!', 'Cheer up, things will get better!']),
    
    # More conversational responses
    (r'(.*) (love|like) (.*)', ['Love is in the air!', 'Love makes the world go round.']),
    
    # Asking for advice
    (r'(.*) advice (.*)', ['Stay positive and keep moving forward!', 'Don’t worry, everything will work out in the end.']),
    
    # Default response if nothing matches
    (r'(.*)', ['Sorry, I didn’t understand that. Can you rephrase?', 'I’m not sure what you mean. Please try again.']),
]

# Create a chatbot with the defined patterns
chatbot = Chat(patterns, reflections)

# Function to get chatbot response
def get_response():
    user_input = user_input_box.get()
    if user_input.strip() != "":  # Ensure there's text entered
        chat_display.config(state=tk.NORMAL)  # Enable text box to insert text
        chat_display.insert(tk.END, "You: " + user_input + "\n")
        user_input_box.delete(0, tk.END)  # Clear input box
        
        if user_input.lower() in ['bye', 'goodbye']:
            chat_display.insert(tk.END, "Chatbot: Goodbye! Have a great day!\n")
            window.quit()  # Close the chat window
        else:
            response = chatbot.respond(user_input)
            # If the chatbot doesn't have a response, repeat the user's message
            if response is None:
                response = f"You said: {user_input}"
            chat_display.insert(tk.END, "Chatbot: " + response + "\n")
        chat_display.config(state=tk.DISABLED)  # Make the text box read-only initially
        chat_display.yview(tk.END)  # Auto-scroll to the latest message

# Set up the main Tkinter window
window = tk.Tk()
window.title("Chatbot")
window.geometry("600x700")

# Set the icon for the window
window.iconbitmap(r"C:\Users\naray\Downloads\chatboticon.ico")  # Set window icon

# Get the screen width and height to center the window
screen_width = window.winfo_screenwidth()
screen_height = window.winfo_screenheight()

# Calculate the position to center the window on the screen
position_top = int(screen_height / 2 - 350)  # 350 is half the height of the window
position_right = int(screen_width / 2 - 300)  # 300 is half the width of the window

# Position the window in the center
window.geometry(f'600x700+{position_right}+{position_top}')

# Set a background color and font for the window
window.config(bg='#d3f4f9')  # Light blue background

# Load and display the chatbot image
chatbot_image_path = r"C:\Users\naray\Downloads\chatbotai.jpg"  # Image file path
chatbot_image = Image.open(chatbot_image_path)
chatbot_image = chatbot_image.resize((100, 100))  # Resize image to fit the window if needed
chatbot_image_tk = ImageTk.PhotoImage(chatbot_image)

# Display the image on the window with some distance up the screen
image_label = tk.Label(window, image=chatbot_image_tk, bg='#d3f4f9')
image_label.place(relx=0.5, rely=0.1, anchor='center')  # Moved the image higher by changing rely value

# Create a label for the title
title_label = tk.Label(window, text="Chatbot", font=("Arial", 24, "bold"), bg='#d3f4f9', fg="#2a2a2a")
title_label.place(relx=0.5, rely=0.2, anchor='center')  # Center title label below the image

# Create a scrollable text area to display chat history with increased size and decoration
chat_display = scrolledtext.ScrolledText(window, wrap=tk.WORD, width=80, height=20, font=("Arial", 12), bg="#e8e8e8", fg="#2a2a2a", bd=2, relief="solid")
chat_display.place(relx=0.5, rely=0.5, anchor='center')  # Center chat display using relative positioning
chat_display.insert(tk.END, "Chatbot: Hello, I am your chatbot. Type 'bye' to end the conversation.\n")
chat_display.config(state=tk.DISABLED)  # Make the text box read-only initially

# Create a user input box with custom style
user_input_box = tk.Entry(window, width=50, font=("Arial", 14), bd=2, relief="solid", fg="#2a2a2a")
user_input_box.place(relx=0.5, rely=0.8, anchor='center')  # Center user input box

# Create a send button with customized style
send_button = tk.Button(window, text="Send", width=10, font=("Arial", 14), bg="#4CAF50", fg="white", relief="raised", command=get_response)
send_button.place(relx=0.5, rely=0.9, anchor='center')  # Center send button

# Add some padding to the window
window.config(padx=20, pady=20)

# Run the Tkinter main loop
window.mainloop()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\naray\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
